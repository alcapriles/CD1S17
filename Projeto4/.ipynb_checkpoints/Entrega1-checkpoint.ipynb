# %% [markdown]
# Entrega final: 16/05

# %% [markdown]
# ## Projeto 4
# Ana Capriles e Lucas Chen Alba

# %% [markdown]
# ## Introdução

# %% [markdown]
# O objetivo deste projeto é criar um contexto prático cuja hipótese principal seja a comparação de médias em duas situações
# distintas (situação A e situação B) e aplicar uma técnica inferencial adequada que compare essas médias populacionais.

# %% [markdown]
# A base de dados escolhida é a australia.soybeans, extraída do pacote Agridat, da linguagem R. Esta base de dados consiste na
# produção, em toneladas métricas por hectare e outras características de 58 variedades genéticas diferentes de soja, em quatro
# localidades diferentes da Austrália, durante dois anos.

# %% [markdown]
# A característica escolhida para o teste é a produção de soja em toneladas por hectare em duas localidades diferentes
# (inserir localidades), ao longo de um mesmo ano (inserir ano).

# %%
Description
Yield and other traits of 58 varieties of soybeans, grown in four locations across two years in Australia.
This is four-way data of Year x Loc x Gen x Trait.
Format
A data frame with 464 observations on the following 10 variables.
env Factor with 8 levels, first character of location and last two characters of year
loc Four locations: Brookstead, Lawes, Nambour, RedlandBay
year Year: 1970 or 1971
gen Genotype factor of soybeans, 1-58
yield Yield, metric tons / hectare
height Height, in meters
lodging Lodging
size Seed size in millimeters
protein Protein in percentage
oil Oil, in percentage


Measurement are available from four locations in Queensland, Australia in two consecutive years
1970, 1971.
The 58 different genotypes of soybeans consisted of 43 lines (40 local Australian selections from a
cross, their two parents, and one other which was used a parent in earlier trials) and 15 other lines
of which 12 were from the US.
Lines 1-40 were local Australian selections from Mamloxi (CPI 172) and Avoyelles (CPI 15939).
No. Line
1-40 Local selections
41 Avoyelles (CPI 15939) Tanzania
42 Hernon 49 (CPI 15948) Tanzania
43 Mamloxi (CPI 172) Nigeria
44 Dorman USA
45 Hampton USA
46 Hill USA
47 Jackson USA
48 Leslie USA
49 Semstar Australia
50 Wills USA
51 C26673 Morocco
52 C26671 Morocco
53 Bragg USA
54 Delmar USA
55 Lee USA
56 Hood USA
57 Ogden USA
58 Wayne USA
Note on the data in Basford and Tukey book. The values for line 58 for Nambour 1970 and Redland
Bay 1971 are incorrectly listed on page 477 as 20.490 and 15.070. They should be 17.350 and
13.000, respectively. In the data set made available here, these values have been corrected.

# %% [markdown]
# ## Análises descritiva e inferencial e explicação dos resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
df = pd.read_excel('Ana.xlsx')

# %%
df.shape
# Out:
# (540, 10)

# %%
df
# Out:
#      loc           gen                      yield  stand rootlodge stalklodge  \
# 0      1  Knoxville,TN            AgriGold A6680W  138,2      91,1          0
# 1      2  Knoxville,TN           AgriGold XA4323W    151      86,1          0
# 2      3  Knoxville,TN             Asgrow XP7555W  139,6      94,4          0
# 3      4  Knoxville,TN                Beck Ex2251  190,1        90          0
# 4      5  Knoxville,TN                 Crow's W54  140,7      88,9          0
# 5      6  Knoxville,TN                 Crow's W55  139,3      88,9          0
# 6      7  Knoxville,TN               Crow's EX551  178,9      88,9          0
# 7      8  Knoxville,TN               Crow's EX552    180      94,4          0
# 8      9  Knoxville,TN     DEKALB Genetics DK703W  166,3      98,9          0
# 9     10  Knoxville,TN     DEKALB Genetics DK631W  169,1      99,4          0
# 10    11  Knoxville,TN    DEKALB Genetics EXP564W  178,4      93,9          0
# 11    12  Knoxville,TN     Golden Harvest EX-106W  194,2      98,3          0
# 12    13  Knoxville,TN           Hoegemeyer 1125W  147,7      97,2          0
# 13    14  Knoxville,TN           Hoegemeyer 1131W  152,3      91,7          0
# 14    15  Knoxville,TN           Hoegemeyer 1142W  146,4        95          0
# 15    16  Knoxville,TN            ICI Seeds 8320W    147        95          0
# 16    17  Knoxville,TN           ICI Seeds N3527W  151,5      92,2          0
# 17    18  Knoxville,TN                  IFSI 90-1  172,9      87,2          0
# 18    19  Knoxville,TN                  IFSI 93-4  192,5      92,8          0
# 19    20  Knoxville,TN                  IFSI 95-2  189,2      94,4          0
# 20    21  Knoxville,TN            LG Seeds NB571W  160,7      92,8          0
# 21    22  Knoxville,TN            LG Seeds NB710W  168,9      94,4          0
# 22    23  Knoxville,TN            LG Seeds NB739W    175      99,4          0
# 23    24  Knoxville,TN            LG Seeds NB742W    156      91,1          0
# 24    25  Knoxville,TN            LG Seeds NB749W  146,5      97,8        0,6
# 25    26  Knoxville,TN              Mycogen 7860W  145,6      87,8          0
# 26    27  Knoxville,TN             Mycogen X6688W  189,6      92,8          0
# 27    28  Knoxville,TN                  NC+ 5633W  166,9      92,8          0
# 28    29  Knoxville,TN                  NC+ 6555W  135,8      99,4          0
# 29    30  Knoxville,TN       Northrup King X6545W  180,6      91,1          0
# ..   ...           ...                        ...    ...       ...        ...
# 510  511     Marion,IA       Northrup King X6955W  196,7       NaN        NaN
# 511  512     Marion,IA              Pioneer 3287W  164,9       NaN        NaN
# 512  513     Marion,IA              Pioneer 3392W  197,6       NaN        NaN
# 513  514     Marion,IA              Pioneer 3443W  197,5       NaN        NaN
# 514  515     Marion,IA              Pioneer 3463W  185,2       NaN        NaN
# 515  516     Marion,IA            Pioneer X1155FW  167,8       NaN        NaN
# 516  517     Marion,IA           SeedTec ST-7545W  154,7       NaN        NaN
# 517  518     Marion,IA         Sturdy Grow SG730W  178,4       NaN        NaN
# 518  519     Marion,IA         Sturdy Grow SG765W  186,3       NaN        NaN
# 519  520     Marion,IA         Sturdy Grow SG777W  197,8       NaN        NaN
# 520  521     Marion,IA         Sturdy Grow SG781W  191,5       NaN        NaN
# 521  522     Marion,IA         Sturdy Grow SG797W  179,9       NaN        NaN
# 522  523     Marion,IA             Trisler T4113W  188,6       NaN        NaN
# 523  524     Marion,IA             Trisler T4211W  185,4       NaN        NaN
# 524  525     Marion,IA             Vineyard V413W  154,7       NaN        NaN
# 525  526     Marion,IA             Vineyard V414W  190,9       NaN        NaN
# 526  527     Marion,IA             Vineyard V424W  169,8       NaN        NaN
# 527  528     Marion,IA             Vineyard V438W  161,2       NaN        NaN
# 528  529     Marion,IA             Vineyard V448W  160,8       NaN        NaN
# 529  530     Marion,IA             Vineyard V449W  181,5       NaN        NaN
# 530  531     Marion,IA               Whisnand 50W  211,9       NaN        NaN
# 531  532     Marion,IA              Whisnand 51AW  208,9       NaN        NaN
# 532  533     Marion,IA              Whisnand 52AW  129,6       NaN        NaN
# 533  534     Marion,IA               Wilson 1780W  174,8       NaN        NaN
# 534  535     Marion,IA               Wilson 1790W  192,5       NaN        NaN
# 535  536     Marion,IA               Wilson E1732  176,6       NaN        NaN
# 536  537     Marion,IA               Wilson E1789    181       NaN        NaN
# 537  538     Marion,IA             Zimmerman Z73W  132,6       NaN        NaN
# 538  539     Marion,IA      Yellow check B73xMo17  223,4       NaN        NaN
# 539  540     Marion,IA  Yellow check Pioneer 3394  196,8       NaN        NaN
#
#     earht flower moisture Unnamed: 9
# 0       0   47,3     67,3       21,7
# 1     0,6     45     67,7       21,5
# 2     0,6   46,3       67       19,8
# 3       0     57     67,3       19,4
# 4     0,6     47     68,7       21,1
# 5     1,2     52     66,7         20
# 6     0,7     47     67,3       20,2
# 7     1,8     49     67,7       19,9
# 8     0,6     47       67       21,3
# 9     1,1     37     65,3       19,1
# 10    0,6     49       68       18,8
# 11    0,6   53,3     66,7       19,1
# 12      0     48     67,7       21,6
# 13    0,6   51,7       70       20,9
# 14    0,6     46     69,3       23,3
# 15    0,6     46     67,3       20,8
# 16    1,2   40,7       63       17,6
# 17    0,6     51       67       21,1
# 18    1,3   48,7     67,3       21,6
# 19    0,6     57       66       19,5
# 20    4,3     40     65,7       16,6
# 21      0     49     65,7       19,8
# 22    1,1   40,3     66,7       20,7
# 23    1,3   34,3     65,3       20,3
# 24      0     48       68       21,3
# 25      0   47,3     66,7       20,9
# 26    1,2   57,7     66,7       19,3
# 27      0     51     67,3       19,9
# 28      0     47       68       20,7
# 29    1,3     52     66,7       20,3
# ..    ...    ...      ...        ...
# 510   NaN     55     91,3       33,1
# 511   NaN     52       89       30,8
# 512   NaN   53,7       92       28,5
# 513   NaN     50       89       29,4
# 514   NaN     50     88,3       26,9
# 515   NaN     53     88,7         30
# 516   NaN     52     94,3         34
# 517   NaN   52,3     91,3         32
# 518   NaN     55     91,3         32
# 519   NaN     54       92       32,7
# 520   NaN   53,3     91,3       34,1
# 521   NaN     57       94       32,5
# 522   NaN     50     90,7       33,3
# 523   NaN     56     91,3       31,7
# 524   NaN   54,7     91,7       30,7
# 525   NaN     46       91         28
# 526   NaN     58       91       33,8
# 527   NaN     49     91,3       33,3
# 528   NaN     51       92       34,4
# 529   NaN     49     91,7       31,4
# 530   NaN     58     91,3         32
# 531   NaN   56,7     93,3       31,5
# 532   NaN     50     91,7       34,7
# 533   NaN   51,7     91,7       33,8
# 534   NaN     52       92       33,4
# 535   NaN   51,7     93,3       34,3
# 536   NaN     58     94,7       34,7
# 537   NaN     59     93,7       33,4
# 538   NaN     52     89,7       32,7
# 539   NaN     48     90,3       26,7
#
# [540 rows x 10 columns]

# %% [markdown]
# ## Conclusão

# %% [markdown]
# ## Referências

# %% [markdown]
# Basford, K. E., and Tukey, J. W. (1999). Graphical analysis of multiresponse data illustrated with a
# plant breeding trial. Chapman and Hall/CRC.
# Retrieved from: http://three-mode.leidenuniv.nl/data/soybeaninf.htm.
# Used with permission of Kaye Basford, Pieter Kroonenberg.
#
# K E Basford. 1982. The Use of Multidimensional Scaling in Analysing Multi-Attribute Genotype
# Response Across Environments, Aust J Agric Res, 33, 473–480.
# baker.barley.uniformity 21
# Kroonenberg, P. M., & Basford, K. E. B. (1989). An investigation of multi-attribute genotype
# response across environments using three-mode principal component analysis. Euphytica, 44, 109–
# 123.
